# %%
import pandas as pd
description_embeddings=pd.read_csv("cve_description_embeddings (3).csv")

# %%
description_embeddings
# Out:
#                0         1         2         3         4         5         6  \
# 0      -0.001640 -0.030970  0.044470 -0.031394 -0.013792  0.003218 -0.022487
# 1      -0.046781 -0.018833  0.046683 -0.006936 -0.029171 -0.041347  0.026462
# 2       0.042660 -0.018914  0.028954  0.018009 -0.024250  0.007726  0.026530
# 3      -0.006042  0.036696  0.017903 -0.016969  0.045420 -0.012018  0.035527
# 4      -0.039202  0.068142  0.024356 -0.021011  0.007158 -0.014803 -0.006108
# ...          ...       ...       ...       ...       ...       ...       ...
# 107082 -0.011986  0.061010  0.032686 -0.028446 -0.029524 -0.023394  0.090123
# 107083 -0.004956 -0.065942  0.019145  0.011628  0.009604  0.002046 -0.019728
# 107084 -0.049817 -0.021449  0.029341 -0.032229  0.009590 -0.030068  0.030462
# 107085  0.023021  0.003177  0.050270 -0.011757 -0.009439  0.035122  0.086489
# 107086  0.001781 -0.043761  0.019851  0.020701  0.039144 -0.003208  0.007968
#
# ...

# %%
description_embeddings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107087 entries, 0 to 107086
# Columns: 769 entries, 0 to Description
# dtypes: float64(768), object(1)
# memory usage: 628.3+ MB

# %%
import pandas as pd
cve_data=pd.read_csv("cve_data_cleaned.csv")

# %%
cve_data=cve_data.drop('Description', axis=1)
cve_data
# Out:
#                CVE_ID                    ASSIGNER             Published_Date  \
# 0       CVE-2011-0199  product-security@apple.com  2011-06-24 20:55:00+00:00
# 1       CVE-2011-0220  product-security@apple.com  2020-02-05 20:15:00+00:00
# 2       CVE-2011-0428               cve@mitre.org  2019-10-29 19:15:00+00:00
# 3       CVE-2011-0467       security@opentext.com  2018-06-07 21:29:00+00:00
# 4       CVE-2011-0469       security@opentext.com  2017-08-17 16:29:00+00:00
# ...               ...                         ...                        ...
# 107082  CVE-2008-7315               cve@mitre.org  2017-10-10 16:29:00+00:00
# 107083  CVE-2008-7316         security@debian.org  2016-05-02 10:59:00+00:00
# 107084  CVE-2008-7319               cve@mitre.org  2017-11-07 21:29:00+00:00
# 107085  CVE-2008-7320               cve@mitre.org  2018-11-18 19:29:00+00:00
# 107086  CVE-2008-7321               cve@mitre.org  2019-08-22 14:15:00+00:00
#
# ...

# %%
cve_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107087 entries, 0 to 107086
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CVE_ID                  107087 non-null  object
#  1   ASSIGNER                107087 non-null  object
#  2   Published_Date          107087 non-null  object
#  3   Last_Modified_Date      107087 non-null  object
#  4   Impact_Score            107087 non-null  float64
#  5   Access_Vector           107087 non-null  object
#  6   Access_Complexity       107087 non-null  object
#  7   Configurations          107087 non-null  object
#  8   Reference_Data          107087 non-null  object
#  9   Year                    107087 non-null  int64
#  10  Base_Score              107087 non-null  float64
#  11  Exploitability_Score    107087 non-null  float64
#  12  Confidentiality_Impact  107087 non-null  object
#  13  Integrity_Impact        107087 non-null  object
# ...

# %%
merged_data = pd.concat([cve_data, description_embeddings], axis=1)
merged_data
# Out:
#                CVE_ID                    ASSIGNER             Published_Date  \
# 0       CVE-2011-0199  product-security@apple.com  2011-06-24 20:55:00+00:00
# 1       CVE-2011-0220  product-security@apple.com  2020-02-05 20:15:00+00:00
# 2       CVE-2011-0428               cve@mitre.org  2019-10-29 19:15:00+00:00
# 3       CVE-2011-0467       security@opentext.com  2018-06-07 21:29:00+00:00
# 4       CVE-2011-0469       security@opentext.com  2017-08-17 16:29:00+00:00
# ...               ...                         ...                        ...
# 107082  CVE-2008-7315               cve@mitre.org  2017-10-10 16:29:00+00:00
# 107083  CVE-2008-7316         security@debian.org  2016-05-02 10:59:00+00:00
# 107084  CVE-2008-7319               cve@mitre.org  2017-11-07 21:29:00+00:00
# 107085  CVE-2008-7320               cve@mitre.org  2018-11-18 19:29:00+00:00
# 107086  CVE-2008-7321               cve@mitre.org  2019-08-22 14:15:00+00:00
#
# ...

# %%
merged_data.to_csv('merged_cve_data.csv', index=False)

# %%
import pandas as pd
cve_data=pd.read_csv('merged_cve_data.csv')

# %%
cve_data
# Out:
#                CVE_ID                    ASSIGNER             Published_Date  \
# 0       CVE-2011-0199  product-security@apple.com  2011-06-24 20:55:00+00:00
# 1       CVE-2011-0220  product-security@apple.com  2020-02-05 20:15:00+00:00
# 2       CVE-2011-0428               cve@mitre.org  2019-10-29 19:15:00+00:00
# 3       CVE-2011-0467       security@opentext.com  2018-06-07 21:29:00+00:00
# 4       CVE-2011-0469       security@opentext.com  2017-08-17 16:29:00+00:00
# ...               ...                         ...                        ...
# 107082  CVE-2008-7315               cve@mitre.org  2017-10-10 16:29:00+00:00
# 107083  CVE-2008-7316         security@debian.org  2016-05-02 10:59:00+00:00
# 107084  CVE-2008-7319               cve@mitre.org  2017-11-07 21:29:00+00:00
# 107085  CVE-2008-7320               cve@mitre.org  2018-11-18 19:29:00+00:00
# 107086  CVE-2008-7321               cve@mitre.org  2019-08-22 14:15:00+00:00
#
# ...

# %%
df = pd.read_csv('your_original_dataset.csv')
df.to_parquet('your_dataset.parquet')
